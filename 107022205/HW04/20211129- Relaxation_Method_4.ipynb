# %% [markdown]
# # Relaxation Methods for Partial Diﬀerential Equations
#
# * Author: Pochung Chen
# * Email: pcchen@phys.nthu.edu.tw
#
# Last updated on 11/8/2021

# %% [markdown]
# ## Physics background
#
# For a region of space containing a charge density $\rho$, the electrostatic potential $V$ satisfies **Poission's equation**:
#
# $$
#   \nabla^2 V
#   = \frac{\partial^2 V}{\partial^2 x} + \frac{\partial^2 V}{\partial^2 y} + \frac{\partial^2 V}{\partial^2 z}
#   = -\frac{1}{\epsilon_0} \rho.
# $$
#
# When $\rho=0$ Poission's equation reduces to **Laplace's equation**:
#
# $$
#   \nabla^2 V
#   = \frac{\partial^2 V}{\partial^2 x} + \frac{\partial^2 V}{\partial^2 y} + \frac{\partial^2 V}{\partial^2 z}
#   = 0.
# $$
#
# From the potential we can derive the electric field,
# $$
#   \vec{E}
#   = -\vec{\nabla}V
#   = \left(-\frac{\partial V}{\partial x}, -\frac{\partial V}{\partial y}, -\frac{\partial V}{\partial z}\right).
# $$

# %% [markdown]
# ## Discretization and the relaxation method
#
# We consider a mesh of grid points that covers the domain of interest. For simplicity we assume in each direction the spacing between grid points is $h$.
#
# $$
#   (x_i, y_j, z_k) = (x_0, y_0, z_0) + h (i, j, k).
# $$
#
# We need to find the discretized version of the differential operator $\nabla^2$.
#
# We first Taylor expand $V(x,y,z)$ in $x$ to second order:
#
# $$
#   V(x\pm h,y,z) = V(x,y,z) \pm h \frac{\partial V}{\partial x} + \frac{1}{2}h^2 \frac{\partial^2 V}{\partial x^2} + \cdots
# $$
#
# so that
#
# $$
#   \frac{\partial^2 V}{\partial x^2} \approx \frac{V(x+h)+V(x-h)-2V(x)}{h^2}
# $$
# and similarly for $y$ and $z$.
#
# We hence obtain the discrete approximation to the laplacian:
#
# $$
#   \nabla^2 V \approx
#   \frac{V(x+h,y,z)+V(x-h,y,z)-2V(x,y,z)}{h^2} + \frac{V(x,y+h,z)+V(x,y-h,z)-2V(x,y,z)}{h^2} + \frac{V(x,y,z+h)+V(x,y,z-h)-2V(x,y,z)}{h^2}
# $$

# %% [markdown]
# ## Laplace's equation
#
# If we use a grid notation
# * $V(x, y, z)=V_{i,j,k}$
# * $V(x+h, y, z)=V_{i+1, j, k}$
# * $V(x, y+h, z)=V_{i, j+1, k}$
# * $V(x, y, z+h)=V_{i, j, k+1}$
#
# then the discretized verion of Laplace's equation becomes
#
# $$
#   h^2 \nabla^2 V = 0 \approx
#   \left( V_{i+1,j,k}+V_{i-1,j,k}+V_{i,j+1,k}+V_{i,j-1,k}+V_{i,j,k+1}+V_{i,j,k-1} \right)
#   -6V_{i,j,k}.
# $$
#
# This can be re-written as
#
# $$
#   V_{i,j,k} = \frac{1}{6}\left( V_{i+1,j,k}+V_{i-1,j,k}+V_{i,j+1,k}+V_{i,j-1,k}+V_{i,j,k+1}+V_{i,j,k-1} \right).
# $$
#
# For effective 2D problems,
#
# $$
#   V_{i,j} = \frac{1}{4}\left( V_{i+1,j}+V_{i-1,j}+V_{i,j+1}+V_{i,j-1} \right).
# $$
#
# For effective 1D problems,
#
# $$
#   V_{i} = \frac{1}{2}\left( V_{i+1}+V_{i-1} \right).
# $$

# %% [markdown]
# ## Poission's equation
#
# If charges are present. First we replace the charge density $\rho(x,y,z)$ by a discrete distribution $\rho_{i,j,k}=\rho(x_i,y_j,z_k)$.
#
# The discretized version of Poisson's equation becomes
#
# $$
#   h^2 \nabla^2 V = -h^2 \frac{1}{\epsilon_0} \rho_{i,j,k} \approx
#   -6V_{i,j,k}.
# $$
#
# This can be re-written as
#
# $$
#   V_{i,j,k} = \frac{1}{6}\left( V_{i+1,j,k}+V_{i-1,j,k}+V_{i,j+1,k}+V_{i,j-1,k}+V_{i,j,k+1}+V_{i,j,k-1} + \frac{1}{\epsilon_0}h^3\rho_{i,j,k} \right).
# $$
#
# For effective 2D problems,
#
# $$
#   V_{i,j} = \frac{1}{4}\left( V_{i+1,j}+V_{i-1,j}+V_{i,j+1}+V_{i,j-1} + \frac{1}{\epsilon_0}h^2\rho_{i,j,k} \right).
# $$
#
# For effective 1D problems,
#
# $$
#   V_{i} = \frac{1}{2}\left( V_{i+1}+V_{i-1} + \frac{1}{\epsilon_0}h\rho_{i,j,k} \right).
# $$

# %% [markdown]
# ### Exact solution in 1D
# In 1D, the Laplace's equation reads
#
# $$
#   \frac{d^2 V(x)}{dx^2} = 0.
# $$
#
# The solution has the form $V(x)=ax+b$ where $a$ and $b$ are constants.

# %% [markdown]
# ## Tasks: Jacobi method and Gauss-Seidel method
#
# * Write a program to compute $V$ in a rectangular domain with Dirichlet boundary conditions.
# * Allow the potentials on all four sides to be specified arbitrarily.
# * The number of grid point can be changed.

# %% [markdown]
# #### Jacobi and Gauss-Seidel methods
#
# * Study the relative speed of the Jacobi and Gauss-Seidel methods.

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, p = plt.subplots(ncols=2, nrows=1, figsize=(10, 5), sharex=True)

fineness = 10
iteration = 50

v_start = 0
v_end   = 100
v_total = (v_end - v_start)/fineness + 1

x_start = 0
x_end   = 100
x_total = v_total

Start_R, Start_G, Start_B = 1, 0, 0
End_R,   End_G,   End_B   = 0, 1, 0

v_array = np.linspace(v_start, v_end, int(v_total))
x_array = np.linspace(x_start, x_end, int(x_total))

R_array = np.linspace(Start_R, End_R, iteration)
G_array = np.linspace(Start_G, End_G, iteration)
B_array = np.linspace(Start_B, End_B, iteration)

vj = np.zeros(int(v_total))
vj[0] = v_start
vj[int(v_total)-1] = v_end

for i in range(1, iteration+1):
    for j in range(1, int(v_total)-1):
        vj[j] = (vj[j-1] + vj[j+1])/2
    if (i % 10 == 1):
        label_name = r'Iteration = ' + str('%d' % i)
        p[0].plot(x_array, vj, '.-', color = [R_array[i], G_array[i], B_array[i]], label = label_name)

p[0].plot(x_array, v_array, '.-k', label = 'Exact')
Lj = p[0].legend(loc='upper left', fontsize=12)
plt.setp(Lj.texts, family='Times New Roman')

vg = np.ones(int(v_total))*(v_start+v_end)/2
vg[0] = v_start
vg[int(v_total)-1] = v_end

for i in range(1, iteration+1):
    for j in range(1, int(v_total)-1):
        vg[j] = (vg[j-1] + vg[j+1])/2
    if (i % 10 == 1):
        label_name = r'Iteration = ' + str('%d' % i)
        p[1].plot(x_array, vg, '.-', color = [R_array[i], G_array[i], B_array[i]], label = label_name)

p[1].plot(x_array, v_array, '.-k', label = 'Exact')
Lg = p[1].legend(loc='upper left', fontsize=12)
plt.setp(Lg.texts, family='Times New Roman')

p[0].set_xlabel('Jacobi Method', fontsize=14, labelpad=10, fontname='Times New Roman')
p[1].set_xlabel('Gauss–Seidel Method', fontsize=14, labelpad=10, fontname='Times New Roman')
# Out:
# Text(0.5, 0, 'Gauss–Seidel Method')

# %% [markdown]
# ### Initial conditions
#
# * Study if the initial guess have a significant impact on overall speed.

# %% [markdown]
# ## Tasks: Contour plots (equipotentials) and electric field
#
# * Write a program to compute $V$ in a rectangular domain with Dirichlet boundary conditions.
# * Allow the potentials on all four sides to be specified arbitrarily.
# * The number of grid point can be changed.
# * Use Jacobi method or Gauss-Seidel method.
# * Use some good initial guess.
# * Plot the equipotentials.
# * Plot the electric fields.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 1000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

# 邊界條件
BCL, BCR, BCU, BCD = (10, 10, 10, -10)
V[:, 0] = BCL
V[:, int(y_total)-1] = BCR
V[0, :] = BCD
V[int(x_total)-1, :] = BCU

for s in range(1, iteration):
    for i in range(1, int(x_total)-1):
        for j in range(1, int(y_total)-1):
            V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
            
Ey, Ex = np.gradient(V)
skip = (slice(None, None, 5),slice(None, None, 5))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale=5)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = .75, color = 'r', arrowstyle='fancy', linewidth = 2*dE**0.5)

p[0].plot(x, Y[20,:],'--w', lw = 2, alpha = .75)
p[1].plot(x, Y[20,:],'--w', lw = 2, alpha = .75)
p[2].plot(x, V[20,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[20,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
# Out:
# (-10.0, 10.0)

# %% [markdown]
# ## Tasks: Adding charges
#
# * Modify your code to allow point charges to be placed at arbitrary mesh points.

# %% [markdown]
# ### Single charge
#
# * Compute the potential due to a single charge.
# * Verify that the potential falls off logarithmically, i.e., if $r\rightarrow 2r$ then the potential decreases by a factor of $\ln 2$ (for a positive charge).

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 1000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

for s in range(1, iteration):
    for i in range(1, int(x_total)-1):
        for j in range(1, int(y_total)-1):
            V[20, 20] = 10
            V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
            
Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 5),slice(None, None, 5))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale=5)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = .75, color = 'r', arrowstyle='fancy', linewidth = 4*dE, cmap ='OrRd')

p[0].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[20,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[20,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
# Out:
# (-10.0, 10.0)

# %% [markdown]
# ### Dipole
#
# * Compute the potential due to an electric dipole.
# * What is the expected $r$ dependence?
# * Does your results have the expacted behavior?

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 1000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

for s in range(1, iteration):
    for j in range(1, int(y_total)-1):
        for i in range(1, int(x_total)-1):
            V[20, 30] = +10
            V[20, 10] = -10
            V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
            
Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 5),slice(None, None, 5))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale=5)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = .75, color = 'r', arrowstyle='fancy', linewidth = 3*dE**0.5)

p[0].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[20,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[20,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
# Out:
# (-10.0, 10.0)

# %% [markdown]
# ## Tasks: Parallesl sheets of charges
#
# * Use your program to calculate the potential for parallel lines of charges.
# * Compute the capacitance.

# %% [markdown]
# ### Method-1
#
# * Use two edges of the domain as the plates.
# * Use periodic boundary conditions in the direction along the plates.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 5000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

# 邊界條件
BCL, BCR, BCU, BCD = (-10, 10, 0, 0)
V[0, :] = BCD
V[int(x_total)-1, :] = BCU
V[:, 0] = BCL
V[:, int(y_total)-1] = BCR

for s in range(1, iteration):
    for j in range(1, int(y_total)-1):
        for i in range(1, int(x_total)-1):
            V[i, j] = (V[i-1, j] + V[i+1, j] + V[i, j-1] + V[i, j+1])/4
            
Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 5),slice(None, None, 5))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale=5)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = .75, color = 'r', arrowstyle='fancy', linewidth = 2*dE)

p[0].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[20,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[20,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
# Out:
# (-10.0, 10.0)

# %% [markdown]
# ### Method-2
#
# * Introduce actual lines of equal and opposite charge **NOT** on the boundaries, and solve Poisson's equation both between and outside the plates.
# * Stretch the liens of charges across the domain and impose periodic boundary conditions in the directions along the sheets.
# * Impose *anti-periodic* boundary conditions in the direction perpendicular to the sheets (make sure you understand why), i.e., $V_{bottom} = -V_{top}$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 1000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

for s in range(1, iteration):
    for j in range(1, int(y_total)-1):
        for i in range(1, int(x_total)-1):
            V[10:30, 30] = +10
            V[10:30, 10] = -10
            V[i, j] = (V[i-1, j] + V[i+1, j] + V[i, j-1] + V[i, j+1])/4
            
Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 5),slice(None, None, 5))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale=5)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = .75, color = 'r', arrowstyle='fancy', linewidth = 2*dE)

p[0].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[20,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[20,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
# Out:
# (-10.0, 10.0)

# %% [markdown]
# ### Method-3
#
# * Now consider two finite slabs.
# * What are the appropriate boundary conditions.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 2000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = 10
y_total = x_total

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

# 邊界條件
BCL, BCR, BCU, BCD = (10, -10, 0, 0)
V[0, :] = BCD
V[int(x_total)-1, :] = BCU
V[:, 0] = BCL
V[:, int(y_total)-1] = BCR

for s in range(1, iteration):
    for i in range(1, int(x_total)-1):
        for j in range(0, int(y_total)):
            if (i >= 0 and i <= int(x_total)-2):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4



Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 5),slice(None, None, 5))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale=5)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = .75, color = 'r', arrowstyle='fancy', linewidth = 2*dE)

p[0].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[20,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[20,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[20,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
# Out:
# (-10.0, 10.0)

# %% [markdown]
# Periodic boundary condition (PBCs) are a set of boundary conditions which are often chosen for approximating a large (infinite) system by using a small part called a unit cell. PBCs are often used in computer simulations and mathematical models.

# %% [markdown]
# ## The Periodic Boundary Condition of Single Charge

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.2
iteration = 1000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

center = 50

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

for s in range(1, iteration):
    for i in range(0, int(x_total)):
        for j in range(0, int(y_total)):
            V[center, center] = 10

            if (i == 0):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
            
            if (i == int(x_total)-1):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, 0])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
            
            if (i >= 0 and i <= int(x_total)-2):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4

Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 10),slice(None, None, 10))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale = 0.5)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = 2, color = 'r', arrowstyle='fancy', linewidth = 10*dE)

p[0].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[center,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[center,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
p[2].set_xlabel('The Value on white dotted line', fontsize=14, labelpad=10, fontname='Times New Roman')
# Out:
# Text(0.5, 0, 'The Value on white dotted line')

# %% [markdown]
# ## The Periodic Boundary Condition of Electric Dipole

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 2000
levels = 50

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

center = int((x_total-1)/2)

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

for s in range(1, iteration):
    for i in range(0, int(x_total)):
        for j in range(0, int(y_total)):
            V[center, center-10] = -10
            V[center, center+10] = +10

            if (i == 0):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
            
            if (i == int(x_total)-1):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, 0])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
            
            if (i >= 0 and i <= int(x_total)-2):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4

Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 5),slice(None, None, 5))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale = 2)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = 1, color = 'r', arrowstyle='fancy', linewidth = 5*dE)

p[0].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[center,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[center,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
p[2].set_xlabel('The Value on white dotted line', fontsize=14, labelpad=10, fontname='Times New Roman')
# Out:
# Text(0.5, 0, 'The Value on white dotted line')

# %% [markdown]
# ## The Periodic Boundary Condition of two finite Slab

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 2000
levels = 20

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

center = int((x_total-1)/2)

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

for s in range(1, iteration):
    for i in range(0, int(x_total)):
        for j in range(0, int(y_total)):
            V[center-10:center+10, center-10] = -10
            V[center-10:center+10, center+10] = +10

            if (i == 0):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
            
            if (i == int(x_total)-1):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, 0])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
            
            if (i >= 0 and i <= int(x_total)-2):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4

Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 2),slice(None, None, 2))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale = 10)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = 1, color = 'r', arrowstyle='fancy', linewidth = 2*dE)

p[0].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[center,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[center,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
p[2].set_xlabel('The Value on white dotted line', fontsize=14, labelpad=10, fontname='Times New Roman')
# Out:
# Text(0.5, 0, 'The Value on white dotted line')

# %% [markdown]
# ## Tasks: Concentric rectangles
#
# * Modify your program to solve for $V$ between two rectangular boundaries held at constant potential.
# * Calculate the surface charge density on the boundary surface. $\lambda = \epsilon_0 \vec{n} \cdot \vec{E}$.
# * Determine the totla charge on each surface. How do they compare?
# * Determine the capacitance of the system.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 0.5
iteration = 2000
levels = 20

x_start = -10
x_end   = +10
x_total = (x_end - x_start)/fineness + 1

y_start = -10
y_end   = +10
y_total = x_total

center = int((x_total-1)/2)

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)

for s in range(1, iteration):
    for i in range(0, int(x_total)):
        for j in range(0, int(y_total)):
            V[center-5:center+6, center-5:center+6] = 10
            V[center-15:center+15, center-15] = 0
            V[center-15:center+15, center+15] = 0
            V[center+15, center-15:center+15] = 0
            V[center-15, center-15:center+15] = 0

            if (i == 0):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
            
            if (i == int(x_total)-1):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, 0])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
            
            if (i >= 0 and i <= int(x_total)-2):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4

Ey, Ex = np.gradient(-V)
skip = (slice(None, None, 2),slice(None, None, 2))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X, Y, V, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X[skip], Y[skip], Ex[skip], Ey[skip], color = 'r', scale = 10)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X, Y, V, levels, cmap=cm.gray)
strm = p[1].streamplot(x, y, Ex, Ey, density = 1, color = 'r', arrowstyle='fancy', linewidth = 2*dE)

p[0].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[1].plot(x, Y[center,:],'--w', lw = 2, alpha = .5)
p[2].plot(x, V[center,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x, Ex[center,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
p[2].set_xlabel('The Value on white dotted line', fontsize=14, labelpad=10, fontname='Times New Roman')
# Out:
# Text(0.5, 0, 'The Value on white dotted line')

# %% [markdown]
# ## Tasks: Elaborations (Bonus!)
#
# If you are ambitious, try to implement
# * Overrelaxation method.
# * Multigruid mehtod.

# %% [markdown]
# ## Multigruid mehtod.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker, cm

fig, p = plt.subplots(ncols=3, nrows=1, figsize=(20, 6))

fineness = 1
iteration = 100
levels = 20

x_start = -5
x_end   = +5
x_total = (x_end - x_start)/fineness + 1

y_start = -5
y_end   = +5
y_total = x_total

x = np.linspace(x_start, x_end, int(x_total))
y = np.linspace(y_start, y_end, int(y_total))

X, Y = np.meshgrid(x, y, indexing = 'xy')
V = np.zeros_like(X)


for s in range(1, iteration):
    for i in range(0, int(x_total)):
        for j in range(0, int(y_total)):

            V[0:int(y_total), 0] = +10 #(x, y)
            V[0:int(y_total), int(x_total)-1] = -10 #(x, y)

            if (i == 0):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, int(x_total)-1] + V[j, i+1])/4
            
            if (i == int(x_total)-1):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, 0])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, 0])/4
            
            if (i >= 0 and i <= int(x_total)-2):
                if (j == 0):
                    V[j, i] = (V[int(y_total)-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4
                if (j == int(y_total)-1):
                    V[j, i] = (V[j-1, i] + V[0, i] + V[j, i-1] + V[j, i+1])/4
                if (j >= 0 and j <= int(y_total)-2):
                    V[j, i] = (V[j-1, i] + V[j+1, i] + V[j, i-1] + V[j, i+1])/4

            V[0:int(y_total), 0] = +10 #(x, y)
            V[0:int(y_total), int(x_total)-1] = -10 #(x, y)

x_total = int(len(x)*2) - 1
y_total = x_total
            
x2 = np.linspace(x_start, x_end, x_total)
y2 = np.linspace(y_start, y_end, y_total)

X2, Y2 = np.meshgrid(x2, y2, indexing = 'xy')
V2 = np.zeros_like(X2)

for i in range(0, len(x)):
    for j in range(0, len(y)):
        V2[2*(j), 2*(i)] = V[j, i]

for i in range(0, len(x)):
    for j in range(0, len(y)):
        if (i <= len(x)-2 and j <= len(y)-2):
            V2[2*(j), 2*(i)+1] = (V2[2*(j), 2*(i)] + V2[2*(j), 2*(i+1)])/2
            V2[2*(j)+1, 2*(i)] = (V2[2*(j), 2*(i)] + V2[2*(j+1), 2*(i)])/2
            V2[2*(j)+1, 2*(i)+1] = (V2[2*(j), 2*(i)] + V2[2*(j), 2*(i+1)] + V2[2*(j+1), 2*(i)] + V2[2*(j+1), 2*(i+1)])/4
        if (i == len(x)-1 and j <= len(y)-2):
            V2[2*(j)+1, 2*(i)] = (V2[2*(j), 2*(i)] + V2[2*(j+1), 2*(i)])/2
        if (i <= len(x)-2 and j == len(y)-1):
            V2[2*(j), 2*(i)+1] = (V2[2*(j), 2*(i)] + V2[2*(j), 2*(i+1)])/2

        
x_total = int(len(x2)*2) - 1
y_total = x_total
center = int((x_total-1)/2)

x3 = np.linspace(x_start, x_end, int(x_total))
y3 = np.linspace(y_start, y_end, int(y_total))

X3, Y3 = np.meshgrid(x3, y3, indexing = 'xy')
V3 = np.zeros_like(X3)

for i in range(0, len(x2)):
    for j in range(0, len(y2)):
        V3[2*(j), 2*(i)] = V2[j, i]

for i in range(0, len(x2)):
    for j in range(0, len(y2)):
        if (i <= len(x2)-2 and j <= len(y2)-2):
            V3[2*(j), 2*(i)+1] = (V3[2*(j), 2*(i)] + V3[2*(j), 2*(i+1)])/2
            V3[2*(j)+1, 2*(i)] = (V3[2*(j), 2*(i)] + V3[2*(j+1), 2*(i)])/2
            V3[2*(j)+1, 2*(i)+1] = (V3[2*(j), 2*(i)] + V3[2*(j), 2*(i+1)] + V3[2*(j+1), 2*(i)] + V3[2*(j+1), 2*(i+1)])/4
        if (i == len(x2)-1 and j <= len(y2)-2):
            V3[2*(j)+1, 2*(i)] = (V3[2*(j), 2*(i)] + V3[2*(j+1), 2*(i)])/2
        if (i <= len(x2)-2 and j == len(y2)-1):
            V3[2*(j), 2*(i)+1] = (V3[2*(j), 2*(i)] + V3[2*(j), 2*(i+1)])/2
        

Ey, Ex = np.gradient(-V3)
skip = (slice(None, None, 2),slice(None, None, 2))
dE = (Ex**2+Ey**2)**(0.5)

p[0].set_xticks(np.linspace(x_start, x_end, 11))
p[0].set_yticks(np.linspace(x_start, x_end, 11))
pvj = p[0].contourf(X3, Y3, V3, levels, cmap=cm.gray)
fig.colorbar(pvj, orientation="horizontal", pad=0.15)
p[0].quiver(X3[skip], Y3[skip], Ex[skip], Ey[skip], color = 'r', scale = 10)


p[1].set_xticks(np.linspace(x_start, x_end, 11))
p[1].set_yticks(np.linspace(y_start, y_end, 11))
p[1].contourf(X3, Y3, V3, levels, cmap=cm.gray)
strm = p[1].streamplot(x3, y3, Ex, Ey, density = 1, color = 'r', arrowstyle='fancy', linewidth = 2*dE)

p[0].plot(x3, Y3[center,:],'--w', lw = 2, alpha = .5)
p[1].plot(x3, Y3[center,:],'--w', lw = 2, alpha = .5)
p[2].plot(x3, V3[center,:],'k', lw = 2)
ax2=p[2].twinx()
ax2.plot(x3, Ex[center,:],'--r', lw = 2)

p[0].grid()
p[1].grid()
p[2].grid()

p[0].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[0].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[1].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[1].set_ylabel('y', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
p[2].set_xlabel('x', fontsize = 14, labelpad = 5, fontname = 'Times New Roman')
p[2].set_ylabel('v', fontsize = 14, labelpad = 0, fontname = 'Times New Roman', rotation = 0)
ax2.set_ylabel('dv', fontsize = 14, labelpad = 5, fontname = 'Times New Roman', rotation = 0)

p[0].set_xlim([x_start, x_end])
p[0].set_ylim([y_start, y_end])
p[0].set_aspect('equal')
p[1].set_xlim([x_start, x_end])
p[1].set_ylim([y_start, y_end])
p[2].set_xlabel('The Value on white dotted line', fontsize=14, labelpad=10, fontname='Times New Roman')
# Out:
# Text(0.5, 0, 'The Value on white dotted line')
